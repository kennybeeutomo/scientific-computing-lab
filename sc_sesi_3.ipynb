# %% [markdown]
# <a href="https://colab.research.google.com/github/kennybeeutomo/scientific-computing-lab/blob/main/sc_sesi_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from scipy.interpolate import interp1d
from scipy.interpolate import CubicSpline
import numpy as np
import matplotlib.pyplot as plt
plt.style.use("ggplot")

# %% [markdown]
# # Linear Interpolation

# %%
def linearPlot(X):
    plt.figure(figsize=(10, 8))
    plt.plot(x, y, "-ob")
    plt.plot(X, y_hat, "ro")
    plt.title("Linear Interpolation at x = " + str(X))
    plt.xlabel("x")
    plt.ylabel("y")
    plt.show()

# %%
x = [0, 1, 2]
y = [1, 3, 2]

f = interp1d(x, y)
y_hat = f(1.5)
print(y_hat)

linearPlot(1.5)
# Out:
# 2.5

# %%
x = [0, 1, 2, 3, 4, 5]
y = [1, 3, 3, 5, 2, 2]

f = interp1d(x, y)

x_lin = np.linspace(0, 5, 100)
y_lin = f(x_lin)

y_hat = f(3.1)
print(y_hat)

linearPlot(3.1)
# Out:
# 4.699999999999999

# %% [markdown]
# # Newton Interpolation

# %%
# %matplotlib inline
def newtonPlot(X):
    plt.figure(figsize=(12, 8))
    plt.plot(x, y, "bo")
    plt.plot(x_new, x_new, "go")
    plt.plot(x_new, y_new)
    plt.title("Newton Interpolation")
    plt.xlabel("x")
    plt.ylabel("y")
    plt.show()


def divided_diff(x, y):
    n = len(y)
    coef = np.zeros((n, n))
    coef[:, 0] = y

    for j in range(1, n):
        for i in range(n - j):
            coef[i][j] = (coef[i+1][j-1] - coef[i][j-1]) / (x[i+j]-x[i])

    return coef


def newton_poly(coef, x_data, x):
    n = len(x_data) - 1
    p = coef[n]
    for k in range(1, n + 1):
        p = coef[n-k] + (x - x_data[n-k]) * p
    return p

# %%
x = np.array([-5, -1, 0, 2])
y = np.array([-2, 6, 1, 3])

a_s = divided_diff(x, y)[0, :]

x_new = np.arange(-5, 2.1, 0.1)
y_new = newton_poly(a_s, x, x_new)

newtonPlot(0)

# %% [markdown]
# # Modul
# Quis Singkat dan cepat
#
# Olympiade tahun 1990, juara lomba sprint 100 m
# adalah Ben Johnson. Catatan larinya ketika 0
# detik kecepatannya adalah 10m/detik. Pada saat
# 5 meter kecepatannya adalah 15m/detik. Pada
# saat 10 meter kecepatannya adalah 20m/detik.
# Berapa kecepatan larinya saat pada jarak 7.2m?
# Jawablah menggunakan coding python linier
# interpolation di bawah

# %%
x = [0, 5, 10]
y = [10, 15, 20]

f = interp1d(x, y)
y_hat = f(7.2)
print(y_hat)

linearPlot(7.2)
print("Kecepatan lari saat jarak 7.2 m adalah", y_hat)
# Out:
# 17.2
# Kecepatan lari saat jarak 7.2 m adalah 17.2
